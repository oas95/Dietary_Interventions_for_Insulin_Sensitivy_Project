# %%
#Importing Dependencies 
import pandas as pd
import re
from pdfminer.high_level import extract_pages, extract_text
import tabula

# %%
#Extracting 
tablesKa18 = tabula.read_pdf("../PyDIonIS/Research_Papers/HCLF/Kahleova et al. 2018.pdf", pages= "all")
tablesVe16 = tabula.read_pdf("../PyDIonIS/Research_Papers/HCLF/Veum et al. 2017.pdf", pages= "all")
tablesCr17 = tabula.read_pdf("../PyDIonIS/Research_Papers/Ketogenic Diet/Crujeuras et al. 2017.pdf", pages= "all")
tablesGa18 = tabula.read_pdf("../PyDIonIS/Research_Papers/HCLF and LCHF/Gardner et al. 2018 Effect of LF vs LC.pdf", pages= "all")
tablesJo06 = tabula.read_pdf("../PyDIonIS/Research_Papers/Ketogenic Diet/Johnston et al. 2006.pdf", pages= "all")
tablesKr16 = tabula.read_pdf("../PyDIonIS/Research_Papers/LCHF/Krebs et al 2016.pdf", pages= "all")
tablesSu13 = tabula.read_pdf("../PyDIonIS/Research_Papers/Ketogenic Diet/Sumithran et al. 2013.pdf", pages= "all")
tableSuz19 = tabula.read_pdf("../PyDIonIS/Research_Papers/LCHF/Suzuki et al. 2019.pdf", pages= "all")
tableZi17 = tabula.read_pdf("../PyDIonIS/Research_Papers/LCHF/Zinn et al. 2017.pdf", pages= "all")
# Out:
# Got stderr: Feb 14, 2023 1:30:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00030 (1) in font MCBCCI+SourceSansRoman-Regular
# Feb 14, 2023 1:30:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00035 (2) in font MCBCCI+SourceSansRoman-Regular
# Feb 14, 2023 1:30:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (3) in font MCBCCI+SourceSansRoman-Regular
# Feb 14, 2023 1:30:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00038 (4) in font MCBCCI+SourceSansRoman-Regular
# Feb 14, 2023 1:30:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00001 (5) in font MCBCCI+SourceSansRoman-Regular
# Feb 14, 2023 1:30:12 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# ...

# %%
#Kahleova study table Extraction HCLF
#Anthropometric Mesures 
AM_df = pd.DataFrame(tablesKa18[0])
#Groups & Outcomes 
GO_df = pd.DataFrame(tablesKa18[1])

GO_df.head()
# Out:
#                           Unnamed: 0        Unnamed: 1        Control Group  \
# 0                  Activity and Diet               NaN                  NaN
# 1                                NaN          Baseline              Week 16
# 2           Physical activity (METs)  2642 (1476–3809)     2575 (1169–3980)
# 3        Caloric intake (kcal.day−1)  1923 (1627–2219)  1582 (1368–1795) **
# 4  Carbohydrates (% of daily energy)  45.5 (42.6–48.4)     46.6 (42.9–50.4)
#
#          Unnamed: 2           Vegan Group  Unnamed: 3              Unnamed: 4  \
# 0               NaN                   NaN         NaN        Treatment Effect
# 1          Baseline               Week 16         NaN                     NaN
# 2  2207 (1444–2969)      2490 (1586–3395)         NaN   +351 (−1143 to +1846)
# 3  1851 (1695–2007)  1450 (1249–1652) ***         NaN      −60 (−352 to +233)
# 4  46.1 (43.5–48.8)  69.6 (67.3–71.8) ***         NaN  +22.3 (+17.7 to +26.9)
#
#   Unnamed: 5
# 0    p-Value
# ...

# %%
#Kahleova study df's to csv
AM_df.to_csv('../PyDIonIS/Data/Kahleova18_Data/Anthro_Table.csv')
GO_df.to_csv('../PyDIonIS/Data/Kahleova18_Data/GroupsOutcomes_Table.csv')

# %%
#Veum Table Extraction
#Athero Measures & BP
AMV_df = pd.DataFrame(tablesVe16[3])

#Energy Intakes Both Groups
EGI_df = pd.DataFrame(tablesVe16[2])

#Changes in Fat Deposition
CFD_df = pd.DataFrame(tablesVe16[5])
Columns = ['Variable and Diet', 'Baseline', '12 wk', 'Score Change', 'Time X Group']
CFD_df.columns = Columns

#CFD missing Couple of Rows so adding missing rows to df
TAF_Row = ['Total abdominal fat, cm', '','', '-3259 (-3663, -2854)***', '0.135']
SubF_Row = ['Subcutaneous fat, cm', '','', '-1769 (-2012, -1525)***', '0.301']
SubLFHC_Row = ['LFHC', '8206 6 2706', '6352 6 2562', '', '']
LFHC_Row = ['LFHC', '14,962 6 4380', '11,465 6 4202','','']
VHFLC_Row = ['VHFLC', '15,202 6 3132', '12,181 6 3165','','']

#Converting missing rows into a Dataframe
Row_Df = pd.DataFrame([TAF_Row, LFHC_Row, VHFLC_Row, SubF_Row, SubLFHC_Row], columns=Columns)
#Creating a copy of OG df and changing column names
CFD_copy = CFD_df.copy()

CFD_Final = pd.concat([Row_Df, CFD_copy], ignore_index= True)

#Changes in Blood Lipids and Glycemic Variaviables 
BLGV_df = pd.DataFrame(tablesVe16[6])

BLGV_df.head()
# Out:
#   4Variable and diet Baseline         4 wk         8 wk      2 12 wk  \
# 0                 TGs, mmol/L          NaN          NaN          NaN
# 1            LFHC 1.45 6 0.53  1.18 6 0.54  1.12 6 0.37  1.04 6 0.38
# 2           VHFLC 1.52 6 0.60  1.22 6 0.48  1.26 6 0.57  0.99 6 0.51
# 3                NEFA, mmol/L          NaN          NaN          NaN
# 4            LFHC 0.45 6 0.14  0.64 6 0.20  0.71 6 0.37  0.53 6 0.18
#
#    Unnamed: 0        3 Score change  Unnamed: 1 Time 3 group
# 0         NaN                   NaN         NaN        0.540
# 1         NaN  20.41 (20.60, 20.21)         NaN          NaN
# 2         NaN  20.53 (20.68, 20.37)         NaN          NaN
# 3         NaN                   NaN         NaN        0.223
# 4         NaN   +0.07 (20.04, 0.18)         NaN          NaN

# %%
#Veum tables to csv
AMV_df.to_csv('../PyDIonIS/Data/Veum16_Data/Anthro_Table.csv')
EGI_df.to_csv('../PyDIonIS/Data/Veum16_Data/EnergyIntakeV_Table.csv')
CFD_df.to_csv('../PyDIonIS/Data/Veum16_Data/Changes_FatDepo_Table.csv')
BLGV_df.to_csv('../PyDIonIS/Data/Veum16_Data/BloodL_GlycemicV_Table.csv')

# %%
#Crujeras has no Tables, might have to manuel data entry or extract data from graphs Table Ketogenic

# %%
#Gardner Table Extraction
#Demographics and Anthrometric Measures and Metabolic Values
#Data Frame Missing Sample size (men & Women), Fasting Insulin, Insulin-30, Metabolic Syndrome count, RER, REE mean, EE, and genotype mean
DAMMV_Ga_df = pd.DataFrame(tablesGa18[6])

#Dietary Intake
Dietary_IntakeGa_df = pd.DataFrame(tablesGa18[7])
Dietary_IntakeGa_df2 = pd.DataFrame(tablesGa18[8])

#Third table is 12month change estimates might not need

# %%
#Gardner to csv
#DAMMV_Ga_df.to_csv('../PyDIonIS/Data/Gardner18_Data/GroupsOutcomes_Table.csv')
Dietary_IntakeGa_df.to_csv('../PyDIonIS/Data/Gardner18_Data/DietaryIntake_Table.csv')
Dietary_IntakeGa_df2.to_csv('../PyDIonIS/Data/Gardner18_Data/DietaryIntake2_Table.csv')

# %%
#Johnston Table Extraction Ketogenic
#Anthro Measures
AMJo_df = pd.DataFrame(tablesJo06[0])
#Metabolic and physiologic measures from baseline
AMJo_df1 = pd.DataFrame(tablesJo06[1])
#Energy Intake df requires data entry, package cannot extract table
ColumnsJo = ['Nutrients', 'KLC diet', 'NLC diet']
Row1 = ['Energy [mJ (kcal)]', '6.25 (1500)', '6.25 (1500)']
Row2 = ['Carbohydrate [g (per of energy)]', '332 (9)', '1572 (42)']
Row3 = ['Sugar (g)', '10', '85']
Row4 = ['Protein [g (per of energy)]', '125 (33)', '117 (31)']
Row5 = ['Fat [g (per of energy)]', '100 (60)', '50 (30)']
Row6 = ['Saturated fat [g (per of energy)]', '35 (21)', '132 (8)']
Row7 = ['Monounsaturated fat [g (per of energy)]', '34 (20)', '16 (10)']
Row8 = ['Polyunsaturated fat [g (per of energy)]', '14 (8)', '7 (4)']
Row9 = ['Cholesterol (mg)', '620', '230']
Row10 = ['Fiber (g)', '152', '30']
Row11 = ['Vitamin A (RE)', '860', '1910']
Row12 = ['Thiamin (mg)', '1.10', '1.50']
Row13 = ['Riboflavin (mg)', '1.40', '2.30']
Row14 = ['Niacin (mg)', '23.5', '16.9']
Row15 = ['Vitamin B-6 (mg)', '1.80', '2.15']
Row16 = ['Vitamin C (mg)', '100', '310']
Row17 = ['Vitamin E (mg)3', '5.902', '10.20']
Row18 = ['Folate (g)', '2202', '440']
Row19 = ['Calcium (mg)', '715', '1110']
Row20 = ['Iron (mg)', '102', '15']
Row21 = ['Magnesium (mg)', '1902', '315']
Row22 = ['Potassium (mg)', '19352', '3535']
Row23 = ['Zinc (mg)', '10.9', '11.3']

EIJo_df = pd.DataFrame([Row1, Row2, Row3, Row4, Row5, Row6, Row7, Row8, Row9, Row10, Row11, Row12, Row13, Row14, Row15, Row16, Row17, Row18, Row19, Row20, Row21, Row22, Row23], columns=ColumnsJo)

# %%
#Johnston to csv
AMJo_df.to_csv('../PyDIonIS/Data/Johnston06_Data/Anthro_Table.csv')
AMJo_df1.to_csv('../PyDIonIS/Data/Johnston06_Data/MetaPhysio_Table.csv')
EIJo_df.to_csv('../PyDIonIS/Data/Johnston06_Data/DietaryIntake_Table.csv')

# %%
#Krebs Table Extraction LCHF
#Tables cant be extracted 
#Characteristics of participants
ColumnsKr = ['', 'Standard carbohydrate group (n=5) Mean (SD) or n', 'Carbohydrate restricted group (n=5) Mean (SD) or n', 'Total (n=10) Mean (SD) or n']
r1 = ['Age (years)', '44.8 (8.3)' '44.5 (10.4)', '44.6 (8.9)']
r2 = ['Gender', '', '', '']
r3 = ['Women', '2', '1', '3']
r4 = ['Men', '3', '4', '7']
r5 = ['Ethnicity – European', '5', '5','10']
r6 = ['Duration of diabetes (years)', '20 (13.1)', '23.6 (9.9)', '21.8 (11.1)']

kr_df = pd.DataFrame([r1, r2, r3, r4, r5, r6], columns=ColumnsKr)

#Outcome Measures by group
ColumnsKr1 = ['', 'Standard carbohydrate group, Baseline (n=5) Mean (SD)', 'Standard carbohydrate group, 12 weeks', 'Carbohydrate restricted group, Baseline (n=5) Mean (SD)', 'Carbohydrate restricted group, 12 weeks (n=5) Mean (SD)']
o1 = ['Weight (kg)', '82.3 (25.6)', '81.9 (25.3)', '83.2 (11.0)', '78.0 (6.4)']
o2 = ['BMI (kg/m2)', '27.7 (6.2)', '27.6 (6.1)', '27.5 (2.2)', '25.8 (1.0)']
o3 = ['HbA1c (mmol/mol)', '57 (9)', '57 (9)', '63 (10)', '55 (4)']
o3a = [' (%)', '7.4 (0.9)', '7.4 (0.9)', '7.9 (0.9)', '7.2 (0.4)']
o4 = ['Total daily insulin (units)', '40.6 (7.8)', '44.8 (12.4)', '64.4 (25.3)', '44.2 (16.5)*†']
o5 = ['Mean CGMS glucose (mmol/L)', '9.3 (1.9)', '10.1 (2.9)', '10.2 (2.3)', '8.9 (0.8)']
o6 = ['MAGE', '7.26 (1.34)', '8.32 (3.53)', '8.46 (1.22)', '8.62 (1.16)']
o7 = ['Systolic blood pressure (mmHg)', '119 (26.1)', '125 (25.3)', '120 (10.9)', '114.5 (16.0)']
o8 = ['Diastolic blood pressure (mmHg)', '74.2 (15.5)', '71.1 (17.9)', '72.4 (11.3)', '64.8 (6.7)']
o9 = ['Serum creatinine (μmol/L)', '76.8 (14.1)', '78.2 (14.1)', '84.6 (15.1)', '83.6 (15.8)']
o10 = ['Total cholesterol (mmol/L)', '4.7 (0.8)', '4.6 (0.6)', '4.7 (0.9)', '4.6 (1.0)']
o11 = ['LDL (mmol/L)', '2.5 (0.7)', '2.5 (0.5)', '2.7 (0.9)', '2.8 (0.8)']
o12 = ['HDL (mmol/L)', '1.8 (0.3)', '1.8 (0.4)', '1.7 (0.2)', '1.5 (0.2)']

kr1_df = pd.DataFrame([o1, o2, o3, o3a, o4, o5 , o6, o7, o8, o9, o10, o11, o12], columns=ColumnsKr1)

#Dietary Intakes
ColumnsKr2 = ['Nutrient', 'Standard carbohydrate group, baseline (n=5) Mean (SD)', 'Standard carbohydrate group, 12 week (n=5) Mean (SD)', 'Carbohydrate restricted group, baseline (n=5) Mean (SD)', 'Carbohydrate restricted group, 12 weeks (n=5) Mean (SD)']
n1 = ['Energy (kcal)', '1922 (410)', '1854 (551)', '1988 (659)', '1391 (159)']
n2 = ['Protein (g)', '97 (32)', '85 (42)', '77 (15)', '76 (16)']
n3 = ['Total Fat (g)', '68 (17)', '77 (15)', '78 (23)', '69 (13)']
n4 = ['Saturated Fat (g)', '24 (9)', '30 (7)', '34 (9)', '24 (7)']
n5 = ['Carbohydrate (g)', '221 (89)', '203 (92)', '219 (90)', '103 (22)*†']
n6 = ['Sugars (g)', '81 (22)', '82 (35)', '93 (26)', '44 (17)*†']
n7 = ['Alcohol (g)', '6 (9)', '2 (4)', '15 (28)', '6 (8)']
n8 = ['Dietary fibre (g)', '21 (5)', '18 (4)', '23 (8)', '19 (3)']
n9 = ['Vitamin C (mg)', '70 (52)', '71 (40)', '126 (34)', '147 (62)']

kr2_df = pd.DataFrame([n1, n2, n3, n4, n5, n6, n7, n8, n9], columns=ColumnsKr2)

kr2_df
# Out:
#             Nutrient Standard carbohydrate group, baseline (n=5) Mean (SD)  \
# 0      Energy (kcal)                                         1922 (410)
# 1        Protein (g)                                            97 (32)
# 2      Total Fat (g)                                            68 (17)
# 3  Saturated Fat (g)                                             24 (9)
# 4   Carbohydrate (g)                                           221 (89)
# 5         Sugars (g)                                            81 (22)
# 6        Alcohol (g)                                              6 (9)
# 7  Dietary fibre (g)                                             21 (5)
# 8     Vitamin C (mg)                                            70 (52)
#
#   Standard carbohydrate group, 12 week (n=5) Mean (SD)  \
# 0                                         1854 (551)
# 1                                            85 (42)
# 2                                            77 (15)
# ...

# %%
#Krebs to csv
kr_df.to_csv('../PyDIonIS/Data/Krebs16_Data/Characteristics_Table.csv')
kr1_df.to_csv('../PyDIonIS/Data/Krebs16_Data/Outcomes_Table.csv')
kr2_df.to_csv('../PyDIonIS/Data/Krebs16_Data/DietaryIntake_Table.csv')

# %%
#Sumithran Table Extraction Ketogenic
#Anthropometric and Bp measures at baseline
df = pd.DataFrame(tablesSu13[0])
#Changes from baseline nutrient hormone and VAS measures
df1 = pd.DataFrame(tablesSu13[2])

df1
# Out:
#                                              Table 2.  \
# 0                                       (mean±s.e.m.)
# 1                                             Measure
# 2                                                 NaN
# 3                                             Fasting
# 4                                            zGlucose
# 5                                            zInsulin
# 6                                            zHOMA-IR
# 7                                                zBHB
# 8                                               zNEFA
# 9                                             zLeptin
# 10                                   zLeptin/fat mass
# 11                                           zGhrelin
# 12                                             bPYY a
# 13                                                GIP
# 14                                           w,bGLP-1
# 15                                                aPP
# ...

# %%
#Sumithran to csv
df.to_csv('../PyDIonIS/Data/Sumithran13_Data/AnthroBP_Table.csv')
df1.to_csv('../PyDIonIS/Data/Sumithran13_Data/BaselineDietraryother_Table.csv')

# %%
#Suzuki table extraction LCHF
#Clinical Parameters df 
Cl_df = tableSuz19[0]
Cl_df2= tableSuz19[1]

# %%
#Suziki to csv
Cl_df.to_csv('../PyDIonIS/Data/Suziki19_Data/ClinicalPar_Table.csv')
Cl_df2.to_csv('../PyDIonIS/Data/Suziki19_Data/ClinicalPar2_Table.csv')

# %%
#Zinn table extraction LCHF
#baseline characteristics table creation
ColumnsZi = ['', 'Control (n = 20)', 'LCHF (n = 20)']
z1 = ['Participant characteristics', '', ''] 
z1a = ['Female', '9 (45)', '5 (24)']
z1b = ['Male', '11 (55)', '16 (76)']
z2 = ['Ethnicity, n (%)', '', '']
z2a = ['NZ/other European', ' 15 (75)', '11(52)']
z2b = ['Maori', '3 (15)', '8 (38)']
z2c = ['PI', '1 (5)', '1 (5)']
z2d = ['Indian', '0 (0)', '1 (0)']
z2e = ['Euroasian', '1 (5)', '0(0)']
z3 = ['Age, mean ± SD (y)', '39.7±9.6', '39.6±7.8']
z4 = ['Body composition and blood marker, mean ± SD Weight (kg)', '', '']
z4a = ['Weight (kg)', '', '']
z4b = ['Female', '85.0±13.4', '85.6±14.8']
z4c = ['Male', '95.1±10.8', '101.3±15.1']
z5 = ['BMI (kg*m2)','', '']
z5a = ['Female', '30.8±3.8', '31.2±5.5'] 
z5b = ['Male', '30.5±3.0', '31.7±4.6']
z6 = ['Waist (cm)', '', ''] 
z6a = ['Female', '92.2±12.6','92.8±7.2']
z6b = ['Male', '101.3±8.5', '101.1±13.9']
z7 = ['HDL cholesterol (mmol/L)', '1.2±0.22', '1.1±0.2']
z8 = ['LDL cholesterol (mmol/L)', '3.0±0.7', '2.8±0.7']
z9 = ['Triglyceride (mmol/L)', '1.5±1.1', '1.4±0.7']
z10 = ['HbA1c (mmol/moL)', '35.2±2.2', '36.0±2.1']
z11 = ['Glucose (mmol/L)', '5.1±0.6', '5.2±0.5']
z12 = ['Insulin (pmol/L)', '64.4±35.4', '81.5±76.9']

base_df = pd.DataFrame([z1, z1a, z1b, z2, z2a, z2b, z2c, z2d, z2e, z3, z4, z4a, z4b, z4c, z5, z5a, z5b, z6, z6a, z6b, z7, z8, z9, z10, z11, z12], columns=ColumnsZi)
#Pre and post antheropometric outcomes 
anthz_df = tableZi17[5]

base_df
# Out:
#                                                       Control (n = 20)  \
# 0                         Participant characteristics
# 1                                              Female           9 (45)
# 2                                                Male          11 (55)
# 3                                    Ethnicity, n (%)
# 4                                   NZ/other European          15 (75)
# 5                                               Maori           3 (15)
# 6                                                  PI            1 (5)
# 7                                              Indian            0 (0)
# 8                                           Euroasian            1 (5)
# 9                                  Age, mean ± SD (y)         39.7±9.6
# 10  Body composition and blood marker, mean ± SD W...
# 11                                        Weight (kg)
# 12                                             Female        85.0±13.4
# ...

# %%
#Zinn to csv
base_df.to_csv('../PyDIonIS/Data/Zinn17_Data/Characteristics_Table.csv')
anthz_df.to_csv('../PyDIonIS/Data/Zinn17_Data/Anthro_Table.csv')
