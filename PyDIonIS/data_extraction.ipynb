# %%
#Importing Dependencies 
import pandas as pd
import re
from pdfminer.high_level import extract_pages, extract_text
import tabula

# %%
#Extracting 
tablesKa18 = tabula.read_pdf("../PyDIonIS/Research_Papers/HCLF/Kahleova et al. 2018.pdf", pages= "all")
tablesVe16 = tabula.read_pdf("../PyDIonIS/Research_Papers/HCLF/Veum et al. 2017.pdf", pages= "all")
tablesCr17 = tabula.read_pdf("../PyDIonIS/Research_Papers/Ketogenic Diet/Crujeuras et al. 2017.pdf", pages= "all")
tablesGa18 = tabula.read_pdf("../PyDIonIS/Research_Papers/HCLF and LCHF/Gardner et al. 2018 Effect of LF vs LC.pdf", pages= "all")
tablesJo06 = tabula.read_pdf("../PyDIonIS/Research_Papers/Ketogenic Diet/Johnston et al. 2006.pdf", pages= "all")
tablesKr16 = tabula.read_pdf("../PyDIonIS/Research_Papers/LCHF/Krebs et al 2016.pdf", pages= "all")
tablesSu13 = tabula.read_pdf("../PyDIonIS/Research_Papers/Ketogenic Diet/Sumithran et al. 2013.pdf", pages= "all")
# Out:
# Got stderr: Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00030 (1) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00035 (2) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (3) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00038 (4) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00001 (5) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00033 (6) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00042 (7) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00045 (8) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00001 (1) in font MCBCCM+SourceSansRoman.613wght
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00048 (1) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00043 (2) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00031 (3) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00028 (4) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00047 (5) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (6) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:39 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00046 (7) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00030 (1) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00035 (2) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (3) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00038 (4) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00001 (5) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00033 (6) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00042 (7) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00045 (8) in font MCBCCI+SourceSansRoman-Regular
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00001 (1) in font MCBCCM+SourceSansRoman.613wght
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00048 (1) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00043 (2) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00031 (3) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00028 (4) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00047 (5) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00032 (6) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:40 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for gid00046 (7) in font MCBCCO+SourceSansRoman-Bold
# Feb 10, 2023 1:53:41 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:41 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:41 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:42 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:42 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:42 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:42 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:43 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
#
# Got stderr: Feb 10, 2023 1:53:44 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:45 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for C23 (1) in font AOLGOG+AdvP4C4E59
# Feb 10, 2023 1:53:45 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for C211 (1) in font AOLHAJ+AdvPSSym
# Feb 10, 2023 1:53:45 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:48 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:48 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:48 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:49 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
#
# Got stderr: Feb 10, 2023 1:53:50 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:51 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Feb 10, 2023 1:53:52 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
#
# Got stderr: Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L50512 (1) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L50514 (2) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L1155 (3) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for H9252 (1) in font GKFAHJ+MathematicalPi-One
# Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for H9253 (2) in font GKFAHJ+MathematicalPi-One
# Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L50141 (4) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:53:59 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L50140 (5) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:54:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L50871 (6) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:54:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L1154 (7) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:54:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for H9262 (3) in font GKFAHJ+MathematicalPi-One
# Feb 10, 2023 1:54:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L50872 (8) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:54:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for L1152 (9) in font GKFAHC+EuropeanPi-Two
# Feb 10, 2023 1:54:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for H6126 (1) in font GKFAPG+MathematicalPi-Five
# Feb 10, 2023 1:54:02 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for H17040 (1) in font GKGAGJ+MathematicalPi-Six
#
# Got stderr: Feb 10, 2023 1:54:08 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for C0 (2) in font HNABCG+AdvP4C4E74
# Feb 10, 2023 1:54:08 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for C2 (3) in font HNABCG+AdvP4C4E74

# %%
#Kahleova study table Extraction 
#Anthropometric Mesures 
AM_df = pd.DataFrame(tablesKa18[0])
#Groups & Outcomes 
GO_df = pd.DataFrame(tablesKa18[1])

GO_df
# Out:
#                            Unnamed: 0          Unnamed: 1  \
# 0                   Activity and Diet                 NaN
# 1                                 NaN            Baseline
# 2            Physical activity (METs)    2642 (1476–3809)
# 3         Caloric intake (kcal.day−1)    1923 (1627–2219)
# 4   Carbohydrates (% of daily energy)    45.5 (42.6–48.4)
# 5            Fats (% of daily energy)    35.6 (32.3–38.9)
# 6        Proteins (% of daily energy)  16.0 (14.94–17.07)
# 7                Cholesterol (mg/day)       290 (220–360)
# 8         Total carbohydrates (g/day)       215 (186–244)
# 9                 Total fiber (g/day)    25.2 (20.9–29.6)
# 10              Soluble fiber (g/day)    6.42 (5.52–7.31)
# 11            Insoluble fiber (g/day)    18.5 (14.7–22.3)
# 12                     Glycemic index    58.1 (56.2–59.9)
# 13                     Starch (g/day)     91.6 (78.6–105)
# 14                    Sucrose (g/day)    36.8 (28.6–44.9)
# 15                    Glucose (g/day)    18.2 (13.5–22.9)
# 16                   Fructose (g/day)    18.1 (13.0–23.3)
# 17                    Lactose (g/day)    5.99 (3.99–8.00)
#
#           Control Group           Unnamed: 2              Vegan Group  \
# 0                   NaN                  NaN                      NaN
# 1               Week 16             Baseline                  Week 16
# 2      2575 (1169–3980)     2207 (1444–2969)         2490 (1586–3395)
# 3   1582 (1368–1795) **     1851 (1695–2007)     1450 (1249–1652) ***
# 4      46.6 (42.9–50.4)     46.1 (43.5–48.8)     69.6 (67.3–71.8) ***
# 5      35.0 (31.5–38.4)     36.1 (34.0–38.1)     17.5 (15.5–19.4) ***
# 6   16.99 (15.45–18.52)  16.77 (15.36–18.19)  12.26 (11.26–13.25) ***
# 7         212 (149–275)        264 (213–315)       6.5 (2.5–10.5) ***
# 8         187 (161–212)        217 (198–236)          260 (222–298) *
# 9      23.5 (19.6–27.4)     24.2 (21.0–27.4)     37.8 (31.4–44.1) ***
# 10     6.80 (5.81–7.79)     7.02 (6.09–7.96)       9.87 (7.34–12.4) *
# 11     16.7 (13.5–19.8)     17.1 (14.6–19.6)     27.7 (23.6–31.7) ***
# 12   57.4 (55.3–59.5) *     57.7 (55.5–59.9)      54.4 (53.4–55.5) **
# 13  70.8 (59.2–82.4) **      95.6 (82.7–109)         125 (102–147) **
# 14     32.9 (25.5–40.3)     36.8 (28.2–45.4)         30.4 (25.9–34.9)
# 15     17.2 (13.1–21.3)     15.7 (13.4–18.0)       20.6 (17.3–23.9) *
# 16     17.5 (13.2–21.8)     17.5 (14.4–20.6)       22.8 (19.4–26.1) *
# 17     6.17 (3.66–8.68)     7.18 (4.93–9.43)     0.56 (0.14–0.98) ***
#
#     Unnamed: 3              Unnamed: 4 Unnamed: 5
# 0          NaN        Treatment Effect    p-Value
# 1          NaN                     NaN        NaN
# 2          NaN   +351 (−1143 to +1846)       0.46
# 3          NaN      −60 (−352 to +233)       0.69
# 4          NaN  +22.3 (+17.7 to +26.9)     <0.001
# 5          NaN  −17.9 (−22.3 to -13.6)     <0.001
# 6          NaN  −5.50 (−7.90 to -3.11)     <0.001
# 7          NaN      −180 (−278 to −82)     <0.001
# 8          NaN   +70.6 (+28.8 to +115)      0.001
# 9          NaN   +15.3 (+8.0 to +22.6)     <0.001
# 10         NaN  +2.46 (−0.13 to +5.05)       0.06
# 11         NaN  +12.5 (+7.16 to +17.7)     <0.001
# 12         NaN     −2.6 (−5.7 to +0.5)       0.10
# 13         NaN  +49.6 (+24.9 to +74.2)     <0.001
# 14         NaN  −2.58 (−14.6 to +9.48)       0.67
# 15         NaN  +5.86 (+0.53 to +11.2)      0.032
# 16         NaN  +5.94 (−0.49 to +12.4)       0.07
# 17         NaN  −6.80 (−10.1 to −3.55)     <0.001

# %%
#Kahleova study df's to csv
AM_df.to_csv('/Users/apple/Dietary_Interventions_for_Insulin_Sensitivy_Project/PyDIonIS/Data/Kahleova18_Data/Anthro_Table.csv')
GO_df.to_csv('/Users/apple/Dietary_Interventions_for_Insulin_Sensitivy_Project/PyDIonIS/Data/Kahleova18_Data/GroupsOutcomes_Table.csv')

# %%
#Veum Table Extraction
#Athero Measures & BP
AMV_df = pd.DataFrame(tablesVe16[3])

#Energy Intakes Both Groups
EGI_df = pd.DataFrame(tablesVe16[2])

#Changes in Fat Deposition
CFD_df = pd.DataFrame(tablesVe16[5])
Columns = ['Variable and Diet', 'Baseline', '12 wk', 'Score Change', 'Time X Group']
CFD_df.columns = Columns

#CFD missing Couple of Rows so adding missing rows to df
TAF_Row = ['Total abdominal fat, cm', '','', '-3259 (-3663, -2854)***', '0.135']
SubF_Row = ['Subcutaneous fat, cm', '','', '-1769 (-2012, -1525)***', '0.301']
SubLFHC_Row = ['LFHC', '8206 6 2706', '6352 6 2562', '', '']
LFHC_Row = ['LFHC', '14,962 6 4380', '11,465 6 4202','','']
VHFLC_Row = ['VHFLC', '15,202 6 3132', '12,181 6 3165','','']

#Converting missing rows into a Dataframe
Row_Df = pd.DataFrame([TAF_Row, LFHC_Row, VHFLC_Row, SubF_Row, SubLFHC_Row], columns=Columns)
#Creating a copy of OG df and changing column names
CFD_copy = CFD_df.copy()

CFD_Final = pd.concat([Row_Df, CFD_copy], ignore_index= True)

#Changes in Blood Lipids and Glycemic Variaviables 
BLGV_df = pd.DataFrame(tablesVe16[6])

BLGV_df
# Out:
#    4Variable and diet Baseline         4 wk         8 wk      2 12 wk  \
# 0                  TGs, mmol/L          NaN          NaN          NaN
# 1             LFHC 1.45 6 0.53  1.18 6 0.54  1.12 6 0.37  1.04 6 0.38
# 2            VHFLC 1.52 6 0.60  1.22 6 0.48  1.26 6 0.57  0.99 6 0.51
# 3                 NEFA, mmol/L          NaN          NaN          NaN
# 4             LFHC 0.45 6 0.14  0.64 6 0.20  0.71 6 0.37  0.53 6 0.18
# 5            VHFLC 0.45 6 0.15  0.70 6 0.19  0.66 6 0.28  0.45 6 0.16
# 6                   TC, mmol/L          NaN          NaN          NaN
# 7             LFHC 5.42 6 1.14  4.60 6 0.94  4.64 6 0.95  4.46 6 0.96
# 8            VHFLC 5.35 6 1.17  5.56 6 1.23  5.78 6 1.22  5.48 6 1.27
# 9                LDL-C, mmol/L          NaN          NaN          NaN
# 10            LFHC 3.68 6 1.07  2.99 6 0.86  2.98 6 0.89  2.90 6 0.85
# 11           VHFLC 3.65 6 1.14  3.99 6 1.15  4.19 6 1.18  3.91 6 1.20
# 12               HDL-C, mmol/L          NaN          NaN          NaN
# 13            LFHC 1.23 6 0.24  1.23 6 0.29  1.23 6 0.27  1.22 6 0.29
# 14           VHFLC 1.05 6 0.30  1.10 6 0.21  1.13 6 0.27  1.19 6 0.29
# 15              TC:HDL-C ratio          NaN          NaN          NaN
# 16            LFHC 4.54 6 1.23  3.92 6 1.23  3.88 6 1.05  3.79 6 1.03
# 17           VHFLC 5.47 6 1.79  5.30 6 1.59  5.41 6 1.60  4.86 6 1.53
# 18              TG:HDL-C ratio          NaN          NaN          NaN
# 19            LFHC 1.24 6 0.59  1.06 6 0.68  0.96 6 0.44  0.91 6 0.42
# 20           VHFLC 1.63 6 0.86  1.21 6 0.69  1.23 6 0.74  0.92 6 0.59
# 21             Glucose, mmol/L          NaN          NaN          NaN
# 22            LFHC 5.11 6 0.46  5.00 6 0.34  4.98 6 0.33  4.78 6 0.44
# 23          5VHFLC 4.94 6 0.42  4.96 6 0.42  5.12 6 0.38  4.85 6 0.42
# 24               Insulin, mU/L          NaN          NaN          NaN
# 25            LFHC 14.1 6 5.47  10.5 6 4.50  9.91 6 5.13  8.56 6 4.92
# 26          5VHFLC 13.3 6 7.43  9.17 6 6.72  11.9 6 6.97  7.62 6 4.31
# 27                INCP, nmol/L          NaN          NaN          NaN
# 28            LFHC 0.88 6 0.22  0.73 6 0.24  0.69 6 0.24  0.62 6 0.22
# 29          5VHFLC 0.89 6 0.31  0.75 6 0.36  0.87 6 0.33  0.67 6 0.29
# 30                    HOMA2-IR          NaN          NaN          NaN
# 31            LFHC 1.95 6 0.53  1.61 6 0.52  1.52 6 0.53  1.35 6 0.51
# 32          5VHFLC 1.95 6 0.69  1.65 6 0.82  1.93 6 0.81  1.47 6 0.66
# 33                    HOMA2-%S          NaN          NaN          NaN
# 34            LFHC 55.8 6 19.1  70.8 6 32.2  76.9 6 35.1  85.4 6 34.6
# 35          5VHFLC 58.7 6 24.1  76.1 6 36.4  63.4 6 33.1  82.9 6 39.8
# 36                    HbA1c, %          NaN          NaN          NaN
# 37             LFHC 5.62 6 0.7            —            —   5.08 6 0.4
# 38            VHFLC 5.58 6 0.5            —            —   5.06 6 0.4
# 39            Glucagon, pmol/L          NaN          NaN          NaN
# 40             LFHC 30.1 6 5.5            —            —   24.7 6 5.6
# 41            VHFLC 32.3 6 9.9            —            —   28.2 6 7.5
#
#     Unnamed: 0        3 Score change  Unnamed: 1 Time 3 group
# 0          NaN                   NaN         NaN        0.540
# 1          NaN  20.41 (20.60, 20.21)         NaN          NaN
# 2          NaN  20.53 (20.68, 20.37)         NaN          NaN
# 3          NaN                   NaN         NaN        0.223
# 4          NaN   +0.07 (20.04, 0.18)         NaN          NaN
# 5          NaN   20.01 (20.07, 0.06)         NaN          NaN
# 6          NaN                   NaN         NaN       ,0.001
# 7          NaN  20.96 (21.23, 20.69)         NaN          NaN
# 8          NaN   +0.13 (20.29, 0.55)         NaN          NaN
# 9          NaN                   NaN         NaN       ,0.001
# 10         NaN  20.78 (21.08, 20.49)         NaN          NaN
# 11         NaN   +0.26 (20.08, 0.60)         NaN          NaN
# 12         NaN                   NaN         NaN        0.034
# 13         NaN   20.01 (20.10, 0.07)         NaN          NaN
# 14         NaN    +0.14 (0.06, 0.22)         NaN          NaN
# 15         NaN                   NaN         NaN        0.552
# 16         NaN  20.75 (21.07, 20.43)         NaN          NaN
# 17         NaN  20.61 (21.20, 20.02)         NaN          NaN
# 18         NaN                   NaN         NaN        0.066
# 19         NaN  20.33 (20.54, 20.13)         NaN          NaN
# 20         NaN  20.70 (20.96, 20.45)         NaN          NaN
# 21         NaN                   NaN         NaN        0.013
# 22         NaN  20.33 (20.53, 20.13)         NaN          NaN
# 23         NaN   20.08 (20.23, 0.06)         NaN          NaN
# 24         NaN                   NaN         NaN        0.886
# 25         NaN  25.52 (27.72, 23.32)         NaN          NaN
# 26         NaN  25.70 (28.09, 23.31)         NaN          NaN
# 27         NaN                   NaN         NaN        0.308
# 28         NaN  20.26 (20.35, 20.16)         NaN          NaN
# 29         NaN  20.22 (20.31, 20.12)         NaN          NaN
# 30         NaN                   NaN         NaN        0.238
# 31         NaN  20.60 (20.82, 20.37)         NaN          NaN
# 32         NaN  20.48 (20.71, 20.25)         NaN          NaN
# 33         NaN                   NaN         NaN        0.330
# 34         NaN    +29.6 (16.5, 42.7)         NaN          NaN
# 35         NaN    +24.2 (10.5, 37.9)         NaN          NaN
# 36         NaN                   NaN         NaN        0.822
# 37         NaN  20.54 (20.75, 20.33)         NaN          NaN
# 38         NaN  20.52 (20.74, 20.29)         NaN          NaN
# 39         NaN                   NaN         NaN        0.479
# 40         NaN  25.39 (26.75, 24.04)         NaN          NaN
# 41         NaN  24.10 (26.30, 21.90)         NaN          NaN

# %%
#Veum tables to csv
AMV_df.to_csv('/Users/apple/Dietary_Interventions_for_Insulin_Sensitivy_Project/PyDIonIS/Data/Veum16_Data/Anthro_Table.csv')
EGI_df.to_csv('/Users/apple/Dietary_Interventions_for_Insulin_Sensitivy_Project/PyDIonIS/Data/Veum16_Data/EnergyIntakeV_Table.csv')
CFD_df.to_csv('/Users/apple/Dietary_Interventions_for_Insulin_Sensitivy_Project/PyDIonIS/Data/Veum16_Data/Changes_FatDepo_Table.csv')
BLGV_df.to_csv('/Users/apple/Dietary_Interventions_for_Insulin_Sensitivy_Project/PyDIonIS/Data/Veum16_Data/BloodL_GlycemicV_Table.csv')
